# %% [markdown]
# # Regression Logistique :
#
# ## Let's see the results :)

# %%
import joblib #SOSO
from rdkit.Chem.Draw import IPythonConsole #Needed to show molecules+
from rdkit.Chem import Draw
from rdkit.Chem import AllChem as Chem
from datetime import datetime
from math import log
import numpy as np
import pandas as pd
import os
from matplotlib import pyplot as plt

# %%
reg_log_es = pd.read_csv('./regression_log_v2/out/test_set_cp_es.csv', sep=',', index_col=0)
reg_log_hs = pd.read_csv('./regression_log_v2/out/test_set_cp_hs.csv', sep=',', index_col=0)

syba_es = pd.read_csv('./syba/out/test_set_cp_es.csv', sep=',', index_col=0)
syba_hs = pd.read_csv('./syba/out/test_set_cp_hs.csv', sep=',', index_col=0)


reg_lin_es = pd.read_csv('./régression_linéaire_v3/out/test_set_cp_es.csv', sep=',', index_col=0)
reg_lin_hs = pd.read_csv('./régression_linéaire_v3/out/test_set_cp_hs.csv', sep=',', index_col=0)


for i in range(np.size(reg_lin_es["nnLin"])):
    reg_lin_es["nnLin"][i] = float(reg_lin_es["nnLin"][i][1:-1])

for i in range(np.size(reg_lin_hs["nnLin"])):
    reg_lin_hs["nnLin"][i] = float(reg_lin_hs["nnLin"][i][1:-1])



lstm_es = pd.read_csv('./LSTM_v5/out/test_set_cp_es.csv', sep=',', index_col=0)
lstm_hs = pd.read_csv('./LSTM_v5/out/test_set_cp_hs.csv', sep=',', index_col=0)


for i in range(np.size(lstm_es["nnLin"])):
    lstm_es["nnLin"][i] = float(lstm_es["nnLin"][i][1:-1])

for i in range(np.size(lstm_hs["nnLin"])):
    lstm_hs["nnLin"][i] = float(lstm_hs["nnLin"][i][1:-1])



v10_es = pd.read_csv('./v10/test_set_cp_es.csv', sep=',', index_col=0)
v10_hs = pd.read_csv('./v10/test_set_cp_hs.csv', sep=',', index_col=0)


for i in range(np.size(v10_es["nnLin"])):
    v10_es["nnLin"][i] = float(v10_es["nnLin"][i][1:-1])

for i in range(np.size(v10_hs["nnLin"])):
    v10_hs["nnLin"][i] = float(v10_hs["nnLin"][i][1:-1])
    
    

v11_es = pd.read_csv('./v11.2/test_set_cp_es.csv', sep=',', index_col=0)
v11_hs = pd.read_csv('./v11.2/test_set_cp_hs.csv', sep=',', index_col=0)


for i in range(np.size(v10_es["nnLin"])):
    v11_es["nnLin"][i] = float(v11_es["nnLin"][i][1:-1])

for i in range(np.size(v10_hs["nnLin"])):
    v11_hs["nnLin"][i] = float(v11_hs["nnLin"][i][1:-1])
# Out:
# <ipython-input-11-d75dce28c729>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reg_lin_es["nnLin"][i] = float(reg_lin_es["nnLin"][i][1:-1])
# <ipython-input-11-d75dce28c729>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reg_lin_hs["nnLin"][i] = float(reg_lin_hs["nnLin"][i][1:-1])
# <ipython-input-11-d75dce28c729>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
all_es = pd.read_csv('./v10/test_set_cp_es.csv', sep=',', index_col=0)
all_hs = pd.read_csv('./v10/test_set_cp_hs.csv', sep=',', index_col=0)

all_mc_es = pd.read_csv('./v10/test_set_mc_es.csv', sep=',', index_col=0)
all_mc_hs = pd.read_csv('./v10/test_set_mc_hs.csv', sep=',', index_col=0)

# %%
all_es['nnLin'] = v10_es['nnLin']
all_hs['nnLin'] = v10_hs['nnLin']

all_mc_es['nnLin'] = v10_mc_es['nnLin']
all_mc_hs['nnLin'] = rl_results_mc_hs['nnLin']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-d7fa192bdda6> in <module>
#       2 all_hs['nnLin'] = v10_hs['nnLin']
#       3
# ----> 4 all_mc_es['nnLin'] = v10_mc_es['nnLin']
#       5 all_mc_hs['nnLin'] = rl_results_mc_hs['nnLin']
#
# NameError: name 'v10_mc_es' is not defined

# %%
all_es.head(10)
# Out:
#                                                 smi  atoms       syba  \
# idx
# ZINC000096135249           Clc1ccc(-c2cnc(Br)s2)cc1     13  21.941954
# ZINC000095730291             CNc1cc(OC2CC2)cc(Br)n1     13  25.360855
# ZINC000231379550               CC1(CNCc2sccc2Br)CC1     13  25.872457
# ZINC000278952989              O=C(NCCCO)c1nc(Cl)cs1     13  33.118938
# ZINC000090590174  CC(C)[C@@H](C)N[C@H](CO)CC(C)(C)C     14  22.576121
# ZINC000307725238     CC1(C)CC[C@@H]1NC[C@]1(C)CCCS1     14  -1.780528
# ZINC000536668157   C[C@@H]1CN(Cc2ccc(Cl)s2)C[C@H]1C     14  32.074153
# ZINC000001407761           Nc1nccc(-c2ccc(Cl)cc2)n1     14  27.728230
# ZINC000397060442      CC[C@@H](CSc1n[nH]c(=NC)s1)OC     14   1.732865
# ZINC000286722495             CCSCCSc1nc(Cl)c(C#N)s1     14  30.074063
#
#                    sascore   scscore  rf_class  rf_prob       bertz  whitlock  \
# idx
# ZINC000096135249  2.225671  2.777942         1     0.86  409.807980        12
# ...

# %%
all_hs.head(10)
# Out:
#                                          smi  atoms       syba   sascore  \
# idx
# GDB17_0  C12C3N1C1C4=C3C35C6C4C4C(N36)C14C25     14 -60.867627  7.476700
# GDB17_1     C1C23C4C5C4C11C4NC44C2C3C52C4N12     14 -62.796939  5.430313
# GDB17_2      C1C23C4C5C4C46C2N4C2C=C6CN5C132     14 -65.124850  6.953781
# GDB17_3     C1C23C4C5N4C4C6N=C(NCC2=C56)C134     14 -64.991358  7.062840
# GDB17_4     C1C23C4CC5=CC6=NCC(C2C=C4)N6C135     15 -65.873614  6.468175
# GDB17_5     C1C23C4CCC2=CC2OC5=C(N4C=N5)C132     15 -45.248495  6.051290
# GDB17_6     C1C23C4CC(O4)C4=C5C=C2C2C5N2C134     14 -64.291384  7.133440
# GDB17_7   C1C23C4NC5CN=C(N6C=CC(=C4)C26)C135     15 -93.739976  6.853249
# GDB17_8      C1C23CC4=CC=C5C6=C4C2C2C6C2C135     14 -39.454839  5.994993
# GDB17_9      C1C23CC4=NOC5=C4C12C(N5)C=CC=C3     15 -60.457829  5.903701
#
#           scscore  rf_class  rf_prob       bertz  whitlock  barone    smcm  \
# idx
# GDB17_0  3.054409         0     0.01  605.442987        64     528  56.940
# ...

# %%
print('Base cp')
a = 0
print('es')
for i in range(10):
    print(sum((all_es['nnLin']<(i+1)/10)) - a)
    a = sum(all_es['nnLin']<(i+1)/10)


print('')    
a = 0
print('hs')
for i in range(10):
    print(sum((all_hs['nnLin']<(i+1)/10)) - a)
    a = sum(all_hs['nnLin']<(i+1)/10)
    

print('')
print('')
print('Base mc')
a = 0
print('es')
for i in range(10):
    print(sum((all_mc_es['nnLin']<(i+1)/10)) - a)
    a = sum(all_mc_es['nnLin']<(i+1)/10)


print('')
a = 0
print('hs')
for i in range(10):
    print(sum((all_mc_hs['nnLin']<(i+1)/10)) - a)
    a = sum(all_mc_hs['nnLin']<(i+1)/10)
# Out:
# Base cp
# es
# 30
# 45
# 43
# 50
# 57
# 75
# 96
# 177
# 373
# 2635
#
# hs
# 2790
# 404
# 168
# 69
# 55
# 34
# 28
# 19
# 10
# 4
#
#
# Base mc
# es
# 5
# 0
# 0
# 1
# 0
# 1
# 2
# 2
# 2
# 27
#
# hs
# 30
# 2
# 1
# 0
# 0
# 2
# 1
# 1
# 1
# 2

# %%
seuil = np.linspace(0, 1, 100)
l = np.size(v10_es["nnLin"])
abs = []
ord = []
sum

plt.figure(figsize = [16, 8])

for i in seuil : 
    abs.append(sum(reg_log_hs['nnLin'] >= i)/l)
    ord.append(sum(reg_log_es['nnLin'] > i)/l)
plt.plot(abs, ord, label = 'régression logistique')
abs = []
ord = []

for i in seuil : 
    abs.append(sum(reg_lin_hs['nnLin'] >= i)/l)
    ord.append(sum(reg_lin_es['nnLin'] > i)/l)
plt.plot(abs, ord, label = 'réseau de neurones linéaire')
abs = []
ord = []


for i in seuil : 
    abs.append(sum(v11_hs['nnLin'] >= i)/l)
    ord.append(sum(v11_es['nnLin'] > i)/l)
plt.plot(abs, ord, label = 'LSTM last version')
plt.plot(abs, abs)


seuil_syba = np.linspace(-150, 150, 1000)

abs = []
ord = []

for i in seuil_syba : 
    abs.append(sum(syba_hs['syba'] >= i)/l)
    ord.append(sum(syba_es['syba'] > i)/l)
plt.plot(abs, ord, label = 'syba')
plt.plot(abs, abs)


plt.legend()
plt.show()
