# %% [markdown]
# # Regression Logistique :
#
# ## Let's see the results

# %%
import joblib #SOSO
from rdkit.Chem.Draw import IPythonConsole #Needed to show molecules+
from rdkit.Chem import Draw
from rdkit.Chem import AllChem as Chem
from datetime import datetime
from math import log
import numpy as np
import pandas as pd
import os

# %%
rl_results_es = pd.read_csv('./v10/test_set_cp_es.csv', sep=',', index_col=0)
rl_results_hs = pd.read_csv('./v10/test_set_cp_hs.csv', sep=',', index_col=0)



for i in range(np.size(rl_results_es["nnLin"])):
    rl_results_es["nnLin"][i] = float(rl_results_es["nnLin"][i][1:-1])

for i in range(np.size(rl_results_hs["nnLin"])):
    rl_results_hs["nnLin"][i] = float(rl_results_hs["nnLin"][i][1:-1])


rl_results_mc_es = pd.read_csv('./v10/test_set_mc_es.csv', sep=',', index_col=0)
rl_results_mc_hs = pd.read_csv('./v10/test_set_mc_hs.csv', sep=',', index_col=0)

for i in range(np.size(rl_results_mc_es["nnLin"])):
    rl_results_mc_es["nnLin"][i] = float(rl_results_mc_es["nnLin"][i][1:-1])

for i in range(np.size(rl_results_mc_hs["nnLin"])):
    rl_results_mc_hs["nnLin"][i] = float(rl_results_mc_hs["nnLin"][i][1:-1])



rl_results_hs.head(5)
# Out:
# <ipython-input-11-e0ec7721b538>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rl_results_es["nnLin"][i] = float(rl_results_es["nnLin"][i][1:-1])
# <ipython-input-11-e0ec7721b538>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rl_results_hs["nnLin"][i] = float(rl_results_hs["nnLin"][i][1:-1])
# <ipython-input-11-e0ec7721b538>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rl_results_mc_es["nnLin"][i] = float(rl_results_mc_es["nnLin"][i][1:-1])
# <ipython-input-11-e0ec7721b538>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rl_results_mc_hs["nnLin"][i] = float(rl_results_mc_hs["nnLin"][i][1:-1])
#                                       smiles  atoms       nnLin
# idx
# GDB17_0  C12C3N1C1C4=C3C35C6C4C4C(N36)C14C25     14   0.0538289
# GDB17_1     C1C23C4C5C4C11C4NC44C2C3C52C4N12     14   0.0093132
# GDB17_2      C1C23C4C5C4C46C2N4C2C=C6CN5C132     14  0.00736979
# GDB17_3     C1C23C4C5N4C4C6N=C(NCC2=C56)C134     14   0.0636712
# GDB17_4     C1C23C4CC5=CC6=NCC(C2C=C4)N6C135     15   0.0129109

# %%
all_es = pd.read_csv('./syba/out/test_set_cp_es.csv', sep=',', index_col=0)
all_hs = pd.read_csv('./syba/out/test_set_cp_hs.csv', sep=',', index_col=0)

all_mc_es = pd.read_csv('./syba/out/test_set_mc_es.csv', sep=',', index_col=0)
all_mc_hs = pd.read_csv('./syba/out/test_set_mc_hs.csv', sep=',', index_col=0)

# %%
all_es['nnLin'] = rl_results_es['nnLin']
all_hs['nnLin'] = rl_results_hs['nnLin']

all_mc_es['nnLin'] = rl_results_mc_es['nnLin']
all_mc_hs['nnLin'] = rl_results_mc_hs['nnLin']

# %%
all_es.head(10)
# Out:
#                                                 smi  atoms       syba  \
# idx
# ZINC000096135249           Clc1ccc(-c2cnc(Br)s2)cc1     13  21.941954
# ZINC000095730291             CNc1cc(OC2CC2)cc(Br)n1     13  25.360855
# ZINC000231379550               CC1(CNCc2sccc2Br)CC1     13  25.872457
# ZINC000278952989              O=C(NCCCO)c1nc(Cl)cs1     13  33.118938
# ZINC000090590174  CC(C)[C@@H](C)N[C@H](CO)CC(C)(C)C     14  22.576121
# ZINC000307725238     CC1(C)CC[C@@H]1NC[C@]1(C)CCCS1     14  -1.780528
# ZINC000536668157   C[C@@H]1CN(Cc2ccc(Cl)s2)C[C@H]1C     14  32.074153
# ZINC000001407761           Nc1nccc(-c2ccc(Cl)cc2)n1     14  27.728230
# ZINC000397060442      CC[C@@H](CSc1n[nH]c(=NC)s1)OC     14   1.732865
# ZINC000286722495             CCSCCSc1nc(Cl)c(C#N)s1     14  30.074063
#
#                    sascore   scscore  rf_class  rf_prob       bertz  whitlock  \
# idx
# ZINC000096135249  2.225671  2.777942         1     0.86  409.807980        12
# ZINC000095730291  2.635986  2.786885         1     0.51  312.483053        12
# ZINC000231379550  2.767051  3.011839         1     0.70  290.869782        11
# ZINC000278952989  2.611751  2.523660         1     0.88  289.774839        12
# ZINC000090590174  3.396056  2.359161         0     0.43  148.890944         6
# ZINC000307725238  4.442706  2.971567         0     0.50  206.367269        14
# ZINC000536668157  3.164625  3.072065         1     0.86  299.991105        15
# ZINC000001407761  1.777729  2.859034         1     0.98  439.375028        12
# ZINC000397060442  4.242446  2.663117         1     0.71  316.386335        14
# ZINC000286722495  3.327050  3.077138         1     0.86  331.817649        14
#
#                   barone    smcm     nnLin
# idx
# ZINC000096135249     297  17.847  0.854959
# ZINC000095730291     255  21.034  0.314561
# ZINC000231379550     234  22.014  0.726332
# ZINC000278952989     225  19.012  0.931289
# ZINC000090590174     171  30.910  0.778486
# ZINC000307725238     231  29.848  0.380715
# ZINC000536668157     276  24.193  0.331182
# ZINC000001407761     324  21.661  0.892805
# ZINC000397060442     237  18.882  0.750818
# ZINC000286722495     252  15.835  0.184561

# %%
all_hs.head(10)
# Out:
#                                          smi  atoms       syba   sascore  \
# idx
# GDB17_0  C12C3N1C1C4=C3C35C6C4C4C(N36)C14C25     14 -60.867627  7.476700
# GDB17_1     C1C23C4C5C4C11C4NC44C2C3C52C4N12     14 -62.796939  5.430313
# GDB17_2      C1C23C4C5C4C46C2N4C2C=C6CN5C132     14 -65.124850  6.953781
# GDB17_3     C1C23C4C5N4C4C6N=C(NCC2=C56)C134     14 -64.991358  7.062840
# GDB17_4     C1C23C4CC5=CC6=NCC(C2C=C4)N6C135     15 -65.873614  6.468175
# GDB17_5     C1C23C4CCC2=CC2OC5=C(N4C=N5)C132     15 -45.248495  6.051290
# GDB17_6     C1C23C4CC(O4)C4=C5C=C2C2C5N2C134     14 -64.291384  7.133440
# GDB17_7   C1C23C4NC5CN=C(N6C=CC(=C4)C26)C135     15 -93.739976  6.853249
# GDB17_8      C1C23CC4=CC=C5C6=C4C2C2C6C2C135     14 -39.454839  5.994993
# GDB17_9      C1C23CC4=NOC5=C4C12C(N5)C=CC=C3     15 -60.457829  5.903701
#
#           scscore  rf_class  rf_prob       bertz  whitlock  barone    smcm  \
# idx
# GDB17_0  3.054409         0     0.01  605.442987        64     528  56.940
# GDB17_1  2.981749         0     0.02  530.404375        64     474  58.583
# GDB17_2  3.452692         0     0.00  552.524984        54     498  49.940
# GDB17_3  3.208831         0     0.01  546.735898        49     453  44.518
# GDB17_4  2.823421         0     0.05  528.654043        42     429  42.155
# GDB17_5  3.616766         0     0.01  586.442633        37     438  35.403
# GDB17_6  3.121194         0     0.02  538.524984        48     480  43.517
# GDB17_7  3.589619         0     0.02  530.985321        43     432  42.018
# GDB17_8  3.253901         0     0.02  598.301028        40     462  44.002
# GDB17_9  3.101054         0     0.01  542.468393        33     420  36.637
#
#               nnLin
# idx
# GDB17_0   0.0370469
# GDB17_1   0.0117701
# GDB17_2   0.0159272
# GDB17_3   0.0224751
# GDB17_4   0.0184481
# GDB17_5   0.0243247
# GDB17_6   0.0247549
# GDB17_7  0.00025275
# GDB17_8   0.0151205
# GDB17_9   0.0155694

# %%
print('faux négatifs SYBA sur test cp : {} %'.format((100*sum(all_es['syba']<0)/len(all_es['syba']))))
print('faux négatifs LSTM v8 sur test cp : {} %'.format(100*sum(all_es['nnLin'] < 0.5)/len(all_es['nnLin'])))
print('faux négatifs SYBA sur test mc : {} %'.format((100*sum(all_mc_es['syba']<0)/len(all_mc_es['syba']))))
print('faux négatifs LSTM v8 sur test mc : {} %'.format(100*sum(all_mc_es['nnLin'] < 0.5)/len(all_mc_es['nnLin'])))

print('faux positifs SYBA sur test cp : {} %'.format(100*sum(all_hs['syba'] > 0)/len(all_es['syba'])))
print('faux positifs LSTM v8 sur test cp : {} %'.format(100*sum(all_hs['nnLin'] > 0.5)/len(all_hs['nnLin'])))
print('faux positifs SYBA sur test mc : {} %'.format((100*sum(all_mc_hs['syba'] > 0)/len(all_mc_hs['syba']))))
print('faux positifs LSTM v8 sur test mc : {} %'.format(100*sum(all_mc_hs['nnLin'] > 0.5)/len(all_mc_hs['nnLin'])))
# Out:
# faux négatifs SYBA sur test cp : 10.862887461602904 %
# faux négatifs LSTM v8 sur test cp : 16.084892488131807 %
# faux négatifs SYBA sur test mc : 12.5 %
# faux négatifs LSTM v8 sur test mc : 17.5 %
# faux positifs SYBA sur test cp : 0.0 %
# faux positifs LSTM v8 sur test cp : 1.926836079307456 %
# faux positifs SYBA sur test mc : 17.5 %
# faux positifs LSTM v8 sur test mc : 15.0 %

# %%
print(len(all_hs['syba']))
# Out:
# 3581
