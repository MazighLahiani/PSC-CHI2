# %% [markdown]
# # Regression Logistique :
#
# ## Let's see the results :)

# %%
from sklearn.externals import joblib
from rdkit.Chem.Draw import IPythonConsole #Needed to show molecules+
from rdkit.Chem import Draw
from rdkit.Chem import AllChem as Chem
from datetime import datetime
import numpy as np
import pandas as pd
# Out:
# /home/samy/.local/lib/python3.6/site-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)

# %%
rl_results_es = pd.read_csv('../out/regression_results/out/test_set_cp_es.csv', sep=',', index_col=0)
rl_results_hs = pd.read_csv('../out/regression_results/out/test_set_cp_hs.csv', sep=',', index_col=0)
rl_results_hs.head(1)
# Out:
#                                       smiles  atoms  regressionLogistique
# idx
# GDB17_0  C12C3N1C1C4=C3C35C6C4C4C(N36)C14C25     14              0.000023

# %%
all_es = pd.read_csv('../out/test_set_cp_es.csv', sep=',', index_col=0)
all_hs = pd.read_csv('../out/test_set_cp_hs.csv', sep=',', index_col=0)

# %%
all_es['regressionLogistique'] = rl_results_es['regressionLogistique']
all_hs['regressionLogistique'] = rl_results_hs['regressionLogistique']

# %%
all_es.head(40)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a5f492d627a1> in <module>
# ----> 1 all_es.head(40)
#
# NameError: name 'all_es' is not defined

# %%
all_hs.head(10)
# Out:
#                                          smi  atoms       syba   sascore  \
# idx
# GDB17_0  C12C3N1C1C4=C3C35C6C4C4C(N36)C14C25     14 -60.867627  7.476700
# GDB17_1     C1C23C4C5C4C11C4NC44C2C3C52C4N12     14 -62.796939  5.430313
# GDB17_2      C1C23C4C5C4C46C2N4C2C=C6CN5C132     14 -65.124850  6.953781
# GDB17_3     C1C23C4C5N4C4C6N=C(NCC2=C56)C134     14 -64.991358  7.062840
# GDB17_4     C1C23C4CC5=CC6=NCC(C2C=C4)N6C135     15 -65.873614  6.468175
# GDB17_5     C1C23C4CCC2=CC2OC5=C(N4C=N5)C132     15 -45.248495  6.051290
# GDB17_6     C1C23C4CC(O4)C4=C5C=C2C2C5N2C134     14 -64.291384  7.133440
# GDB17_7   C1C23C4NC5CN=C(N6C=CC(=C4)C26)C135     15 -93.739976  6.853249
# GDB17_8      C1C23CC4=CC=C5C6=C4C2C2C6C2C135     14 -39.454839  5.994993
# GDB17_9      C1C23CC4=NOC5=C4C12C(N5)C=CC=C3     15 -60.457829  5.903701
#
#           scscore  rf_class  rf_prob       bertz  whitlock  barone    smcm  \
# idx
# GDB17_0  3.054409         0     0.01  605.442987        64     528  56.940
# ...
