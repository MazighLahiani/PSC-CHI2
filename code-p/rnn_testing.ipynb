# %%
#from sklearn.externals import joblib 
import joblib
from rdkit.Chem.Draw import IPythonConsole #Needed to show molecules+
from rdkit.Chem import Draw
from rdkit.Chem import AllChem as Chem
import gzip
import os
import sys
import csv

from syba.syba import SybaClassifier, SmiMolSupplier
import statsmodels.api as sm
from datetime import datetime
import tensorflow as tf

from tensorflow import keras
import numpy as np

from tensorflow.keras import optimizers

from tensorflow.keras import layers
from tensorflow.keras import models

# %%
from tensorflow.keras import optimizers
model = models.Sequential()
model.add(layers.LSTM(128, input_shape=(None, 1024,)))
model.add(layers.Dense(64, activation='relu'))#, input_shape=(1024,)))
model.add(layers.Dense(32, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))
model.compile(optimizer=optimizers.RMSprop(lr=0.001),
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
def create_my_model():
    model = keras.Sequential()
    model.add(layers.Embedding(input_dim=1024, output_dim=1))
    model.add(layers.LSTM(128))
    model.add(layers.Dense(128))
    model.add(layers.Dense(64))
    model.add(layers.Dense(32))
    model.add(layers.Dense(1, activation='sigmoid'))
    model.compile(optimizer=optimizers.RMSprop(lr=0.001), loss='binary_crossentropy', metrics=['mae', 'accuracy'])
    return model

# %%
def create_my_model_v6():
    model = keras.Sequential()
    # Add an Embedding layer expecting input vocab of size 1000, and
    # output embedding dimension of size 64.
    model.add(layers.Embedding(input_dim=1024, output_dim=1))

    # Add a LSTM layer with 128 internal units.
    model.add(layers.LSTM(128))
    # Add a Dense layer with 10 units.
    model.add(layers.Dense(64))
    model.add(layers.Dense(32))
    model.add(layers.Dense(1, activation='sigmoid'))
    model.compile(optimizer=optimizers.RMSprop(lr=0.001), loss='binary_crossentropy', metrics=['mae', 'accuracy'])
    #model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
    return model


def create_my_model7():
    model = keras.Sequential()
    model.add(layers.Embedding(input_dim=1024, output_dim=1))
    model.add(layers.LSTM(264))
    model.add(layers.Dense(264))
    model.add(layers.Dense(128))
    model.add(layers.Dense(64))
    model.add(layers.Dense(32))
    model.add(layers.Dense(1, activation='sigmoid'))
    model.compile(optimizer=optimizers.RMSprop(lr=0.001), loss='binary_crossentropy', metrics=['mae', 'accuracy'])
    return model

# %%
def create_my_model10():
    model = keras.Sequential()
    model.add(layers.Embedding(input_dim=1024, output_dim=100))
    model.add(layers.LSTM(264))
    model.add(layers.Dense(264))
    model.add(layers.Dense(128))
    model.add(layers.Dense(64))
    model.add(layers.Dense(32))
    model.add(layers.Dense(1, activation='sigmoid'))
    model.compile(optimizer=optimizers.RMSprop(lr=0.001), loss='binary_crossentropy', metrics=['mae', 'accuracy'])
    return model

# %%
def create_my_model11():
    model = keras.Sequential()
    model.add(layers.Embedding(input_dim=1024, output_dim=264))
    model.add(layers.LSTM(264))
    model.add(layers.Dense(264))
    model.add(layers.Dense(128))
    model.add(layers.Dense(64))
    model.add(layers.Dense(32))
    model.add(layers.Dense(1, activation='sigmoid'))
    model.compile(optimizer=optimizers.RMSprop(lr=0.001), loss='binary_crossentropy', metrics=['mae', 'accuracy'])
    return model

# %%
rnn_load = create_my_model11()
rnn_load.load_weights('./rnn_lstm_V11.1000.10_weights.h5')
rnn_load.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, None, 264)         270336
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 264)               558624
# _________________________________________________________________
# dense_3 (Dense)              (None, 264)               69960
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               33920
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 943,209
# Trainable params: 943,209
# Non-trainable params: 0
# _________________________________________________________________

# %%
rnn_load = create_my_model()
rnn_load.load_weights('./rnn_lstm_V8.1000.10_weights.h5')
rnn_load.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, None, 1)           1024
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 128)               66560
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_5 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 94,465
# Trainable params: 94,465
# Non-trainable params: 0
# _________________________________________________________________

# %%
rnn_load = create_my_model10()
rnn_load.load_weights('./rnn_lstm_V10.1000.10_weights.h5')
rnn_load.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, None, 100)         102400
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 264)               385440
# _________________________________________________________________
# dense_3 (Dense)              (None, 264)               69960
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               33920
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 602,089
# Trainable params: 602,089
# Non-trainable params: 0
# _________________________________________________________________

# %%
nBits = 1024

inpath = "../data/romain/"
outpath = "../out/RNN/V6/"
i = 0
files = ["pub1.csv"]
for f in files:
    with open(outpath+f, "w") as out:
        out.write("idx,smiles,atoms,LSTM\n")
        print(open(inpath+f, mode="rt"))
        test = np.array([np.array(Chem.GetMorganFingerprintAsBitVect(spls[0],2,nBits=nBits)) for spls in SmiMolSupplier(open(inpath+f, mode="rt"), header=True, smi_col=0)])
        pr = rnn_load.predict(test)
        print(pr)
        print(len(pr))
# Out:
# <_io.TextIOWrapper name='../data/romain/pub1.csv' mode='rt' encoding='UTF-8'>
# [[0.10855246]
#  [0.10855246]
#  [0.10855246]
#  [0.10626462]
#  [0.10855246]
#  [0.11897656]
#  [0.10855246]
#  [0.10855246]
#  [0.01563257]
#  [0.20586413]
#  [0.04011655]
#  [0.02732855]
#  [0.30391163]
#  [0.04263917]
#  [0.26082706]
#  [0.09090751]
#  [0.57336575]
#  [0.10439733]
#  [0.66365355]
#  [0.07446569]
#  [0.23679551]
#  [0.48782074]
#  [0.18724161]
#  [0.22761852]
#  [0.07488617]
#  [0.09351397]
#  [0.14982134]
#  [0.14982134]
#  [0.14982134]
#  [0.14982134]
#  [0.8817674 ]
#  [0.14982134]
#  [0.14982134]
#  [0.14982134]
#  [0.14982134]
#  [0.14982134]
#  [0.14982134]
#  [0.24253333]
#  [0.10393909]
#  [0.297386  ]
#  [0.92068213]
#  [0.11468145]
#  [0.5319365 ]
#  [0.1852631 ]
#  [0.11468145]
#  [0.11468145]
#  [0.5319365 ]
#  [0.1852631 ]
#  [0.11468145]
#  [0.3096097 ]
#  [0.07096884]
#  [0.1982947 ]
#  [0.5085512 ]
#  [0.29720968]
#  [0.29720968]
#  [0.13762066]
#  [0.3219191 ]
#  [0.3219191 ]
#  [0.40428793]
#  [0.25887656]
#  [0.18261746]
#  [0.18261746]
#  [0.18261746]
#  [0.18261746]
#  [0.18261746]
#  [0.18261746]
#  [0.18261746]
#  [0.18261746]
#  [0.11974162]
#  [0.1638987 ]
#  [0.11974162]]
# 71

# %%
rnn_load = create_my_model_v6()
rnn_load.load_weights('./rnn_lstm_V6.1000.10_weights.h5')
rnn_load.summary()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-15-c47626719d52> in <module>
#       1 rnn_load = create_my_model_v6()
# ----> 2 rnn_load.load_weights('./rnn_lstm_V6.1000.10_weights.h5')
#       3 rnn_load.summary()
#
# ~/anaconda3/envs/rdkit-env/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in load_weights(self, filepath, by_name, skip_mismatch, options)
#    2202           'first, then load the weights.')
#    2203     self._assert_weights_created()
# -> 2204     with h5py.File(filepath, 'r') as f:
#    2205       if 'layer_names' not in f.attrs and 'model_weights' in f:
#    2206         f = f['model_weights']
#
# ~/anaconda3/envs/rdkit-env/lib/python3.6/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, **kwds)
#     406                 fid = make_fid(name, mode, userblock_size,
#     407                                fapl, fcpl=make_fcpl(track_order=track_order),
# --> 408                                swmr=swmr)
#     409
#     410             if isinstance(libver, tuple):
#
# ~/anaconda3/envs/rdkit-env/lib/python3.6/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     171         if swmr and swmr_support:
#     172             flags |= h5f.ACC_SWMR_READ
# --> 173         fid = h5f.open(name, flags, fapl=fapl)
#     174     elif mode == 'r+':
#     175         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (file signature not found)

# %%
#Load syba
syba = SybaClassifier()
syba.fitDefaultScore()

# %%
i = 0

nBits = 1024
np.set_printoptions(threshold=sys.maxsize)
inpath = "../data/"
outpath = "../out/RNN/V11/"
files = ["test_set_mc_es.csv", "test_set_mc_hs.csv", "test_set_cp_es.csv", "test_set_cp_hs.csv"]
for f in files:
    with open(inpath+f) as inp, open(outpath+f, "w") as out:
        header = inp.readline().strip()
        out.write(header)
        out.write("idx,smiles,atoms,LstmScoreV10\n")
        data = np.array([np.array(Chem.GetMorganFingerprintAsBitVect(spls[0],2,nBits=nBits)) for spls in SmiMolSupplier(open(inpath+f, mode="rt"), header=True, smi_col=1)])    
        pr = rnn_load.predict(data)
        i = 0
        for line in inp:
            idx, smi, atoms = line.strip().split(",")
            out.write("{},{},{},{}\n".format(idx, smi, atoms, pr[i]))
            #print("{},{},{},{}\n".format(idx, smi, atoms, data[i]))
            i += 1

# %%
i = 0

nBits = 1024

inpath = "../data/"
outpath = "../out/claire/"
files = ["test_set_mc_es.csv", "test_set_mc_hs.csv", "test_set_cp_es.csv", "test_set_cp_hs.csv"]
for f in files:
    with open(inpath+f) as inp, open(outpath+f, "w") as out:
        header = inp.readline().strip()
        out.write(header)
        out.write("idx,smiles,atoms,SybaScore,LstmScore\n")
        data = np.array([np.array(Chem.GetMorganFingerprintAsBitVect(spls[0],2,nBits=nBits)) for spls in SmiMolSupplier(open(inpath+f, mode="rt"), header=True, smi_col=1)])    
        pr = rnn_load.predict(data)
        i = 0
        for line in inp:
            idx, smi, atoms = line.strip().split(",")
            out.write("{},{},{},{}\n".format(idx, smi, atoms, pr[i]))
            i += 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-13a30a67bd59> in <module>
#      12         out.write("idx,smiles,atoms,SybaScore,LstmScore\n")
#      13         data = np.array([np.array(Chem.GetMorganFingerprintAsBitVect(spls[0],2,nBits=nBits)) for spls in SmiMolSupplier(open(inpath+f, mode="rt"), header=True, smi_col=1)])
# ---> 14         pr = rnn_load.predict(data)
#      15         i = 0
#      16         for line in inp:
#
# NameError: name 'rnn_load' is not defined

# %%
nBits = 1024

inpath = "../data/"
outpath = "../out/RNN/V10/"
i = 0
files = ["test_set_mc_es.csv", "test_set_mc_hs.csv", "test_set_cp_es.csv", "test_set_cp_hs.csv"]
for f in files:
    with open(outpath+f, "w") as out:
        out.write("idx,smiles,atoms,LSTM_V8\n")
        test = np.array([np.array(Chem.GetMorganFingerprintAsBitVect(spls[0],2,nBits=nBits)) for spls in SmiMolSupplier(open(inpath+f, mode="rt"), header=True, smi_col=1)])
        
        pr = rnn_load.predict(test)
        print(pr)
        print(len(pr))
        """
        
        for fps in finger_prints:
            print("wesh: ", i)
            i += 1
            fps = np.array(fps)
            
            fps = fps.reshape((1024))
            fps = fps.astype('float32')
            print(np.shape(fps))
            print(rnn_load.predict(fps))
            print(len(rnn_load.predict(fps)))
            print(model.predict([fps]))
            print(len(model.predict([fps])))
            break;
            #out.write("{},{},{},{}\n".format(idx, smi, atoms, rnn_load.predict(fps)))
        print("Fichier " + f + " traité")
print("Phase 1 fini")
"""
"""

#          INP_FILENAME,      SMI_COL,  OUT_FILENAME
files = [("structures_1.csv.gz", 2, "train_set_hs.csv"), ("structures_2.csv.gz", 1, "train_set_es.csv")]
for f, col, out_filename in files:
    with open(outpath+f, "w") as out:
        out.write("idx,smiles,atoms,LSTM\n")
        finger_prints = [Chem.GetMorganFingerprintAsBitVect(spls[0],2,nBits=nBits) for spls in SmiMolSupplier(open(inpath+f, mode="rt"), header=True, smi_col=1)]
        for fps in finger_prints:
            fps = np.array(fps)
            print("wesh: ", i)
            i += 1
            out.write("{},{},{},{}\n".format(idx, smi, atoms, rnn_load.predict(fps)))
        print("Fichier " + f + " traité")

print("Phase 2 fini")


files = ["smiles_fig7.csv"]
for f in files:
    with open(outpath+f, "w") as out:
        out.write("idx,smiles,atoms,LSTM\n")
        finger_prints = [Chem.GetMorganFingerprintAsBitVect(spls[0],2,nBits=nBits) for spls in SmiMolSupplier(open(inpath+f, mode="rt"), header=True, smi_col=1)]
        for fps in finger_prints:
            fps = np.array(fps)
            print("wesh: ", i)
            i += 1
            out.write("{},{},{},{}\n".format(idx, smi, atoms, rnn_load.predict(fps)))
        print("Fichier " + f + " traité")
        
print("Phase 3 fini")
"""
# Out:
# [[0.8007592 ]
#  [0.88534665]
#  [0.8226272 ]
#  [0.3560577 ]
#  [0.13707045]
#  [0.19892034]
#  [0.31953025]
#  [0.22855723]
#  [0.51625454]
#  [0.662784  ]
#  [0.42380953]
#  [0.6078573 ]
#  [0.70078284]
#  [0.205944  ]
#  [0.55376995]
#  [0.7070783 ]
#  [0.21317461]
#  [0.3621719 ]
#  [0.40415382]
#  [0.51726496]
#  [0.6660964 ]
#  [0.1959464 ]
#  [0.29606676]
#  [0.6862525 ]
#  [0.38606095]
#  [0.80658996]
#  [0.22977766]
#  [0.42611015]
#  [0.7059197 ]
#  [0.32697624]
#  [0.80891   ]
#  [0.06048879]
#  [0.8983873 ]
#  [0.01888046]
#  [0.05558366]
#  [0.12424192]
#  [0.25718915]
#  [0.8084855 ]
#  [0.10863999]
#  [0.32916844]]
# 40
# [[0.13008538]
#  [0.17335051]
#  [0.2562237 ]
#  [0.04508147]
#  [0.04167753]
#  [0.7996596 ]
#  [0.3956424 ]
#  [0.03829241]
#  [0.09672877]
#  [0.07817331]
#  [0.06890941]
#  [0.10240787]
#  [0.25254056]
#  [0.14627886]
#  [0.1420913 ]
#  [0.27591482]
#  [0.04799765]
#  [0.8513536 ]
#  [0.9360416 ]
#  [0.5872858 ]
#  [0.03677341]
#  [0.08647299]
#  [0.705526  ]
#  [0.3036367 ]
#  [0.10824242]
#  [0.11367077]
#  [0.3123527 ]
#  [0.04469225]
#  [0.19254807]
#  [0.14857092]
#  [0.10180134]
#  [0.15532407]
#  [0.01347411]
#  [0.29791635]
#  [0.04276842]
#  [0.07216737]
#  [0.03014109]
#  [0.16397083]
#  [0.08730021]
#  [0.16445702]]
# 40
# [[0.93955475]
#  [0.18289694]
#  [0.63430196]
#  ...
#  [0.8148194 ]
#  [0.26120162]
#  [0.13506383]]
# 3581
# [[0.19657633]
#  [0.17641321]
#  [0.13883701]
#  ...
#  [0.13618067]
#  [0.27537435]
#  [0.36073744]]
# 3581
# '\n\n#          INP_FILENAME,      SMI_COL,  OUT_FILENAME\nfiles = [("structures_1.csv.gz", 2, "train_set_hs.csv"), ("structures_2.csv.gz", 1, "train_set_es.csv")]\nfor f, col, out_filename in files:\n    with open(outpath+f, "w") as out:\n        out.write("idx,smiles,atoms,LSTM\n")\n        finger_prints = [Chem.GetMorganFingerprintAsBitVect(spls[0],2,nBits=nBits) for spls in SmiMolSupplier(open(inpath+f, mode="rt"), header=True, smi_col=1)]\n        for fps in finger_prints:\n            fps = np.array(fps)\n            print("wesh: ", i)\n            i += 1\n            out.write("{},{},{},{}\n".format(idx, smi, atoms, rnn_load.predict(fps)))\n        print("Fichier " + f + " traité")\n\nprint("Phase 2 fini")\n\n\nfiles = ["smiles_fig7.csv"]\nfor f in files:\n    with open(outpath+f, "w") as out:\n        out.write("idx,smiles,atoms,LSTM\n")\n        finger_prints = [Chem.GetMorganFingerprintAsBitVect(spls[0],2,nBits=nBits) for spls in SmiMolSupplier(open(inpath+f, mode="rt"), header=True, smi_col=1)]\n        for fps in finger_prints:\n            fps = np.array(fps)\n            print("wesh: ", i)\n            i += 1\n            out.write("{},{},{},{}\n".format(idx, smi, atoms, rnn_load.predict(fps)))\n        print("Fichier " + f + " traité")\n        \nprint("Phase 3 fini")\n'

# %%
nBits = 1024

inpath = "../data/marjo"
outpath = "../out/RNN/Marjo"

files = ["savith.csv", "scubidooth.csv", "gdb_complexth.csv", "nonpherth.csv", "zinc_randomth.csv"]

for f in files:
    with open(inpath+f) as inp, open(outpath+f, "w") as out:
        header = inp.readline().strip()
        #out.write(header)
        out.write("smiles,syba,LstmScore\n")
        
        data = np.array([np.array(Chem.GetMorganFingerprintAsBitVect(spls[0],2,nBits=nBits)) for spls in SmiMolSupplier(open(inpath+f, mode="rt"), header=True, smi_col=0)])    
        pr = rnn_load.predict(data)
        i = 0
        for line in inp:
            smi = line.strip().split(",")[0]
            #fingerprint = np.array(Chem.GetMorganFingerprintAsBitVect(smi,2,nBits=nBits)) 
            out.write("{},{},{}\n".format(smi, syba.predict(smi), pr[0][i][0]))
            i += 1

# %%
nBits = 1024
i = 0
inpath = "../data/"
outpath = "../out/RNN/LSTM_V1"
files = ["test_set_mc_es.csv", "test_set_mc_hs.csv", "test_set_cp_es.csv", "test_set_cp_hs.csv"]
for f in files:
    with open(inpath+f) as inp, open(outpath+f, "w") as out:
        header = inp.readline().strip()
        out.write(header)
        out.write("idx,smiles,atoms,SybaScore,LstmScore\n")
        data = np.array([np.array(Chem.GetMorganFingerprintAsBitVect(spls[0],2,nBits=nBits)) for spls in SmiMolSupplier(open(inpath+f, mode="rt"), header=True, smi_col=1)])    
        pr = rnn_load.predict(data)
        i = 0
        for line in inp:
            idx, smi, atoms = line.strip().split(",")
            out.write("{},{},{},{}\n".format(idx, smi, atoms, syba.predict(smi), pr[i]))
            i += 1
